# %% [markdown]
# # Trying to implement naive bayes in a  small dataset
#
# This is not working. Please check the custom naive bayes ipynb.

# %%
# import required libraries
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
 
# Creating the distribution
data = np.arange(1,10,0.01)
pdf = norm.pdf(data ,loc = 5.3 , scale = 1 )
  
#Visualizing the distribution
 
sb.set_style('whitegrid')
sb.lineplot(data, pdf , color = 'black')
plt.xlabel('Heights')
plt.ylabel('Probability Density')
# Out:
# /home/akshajsr/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Probability Density')

# %%
norm(loc = 4 , scale = 1).cdf(4.5)
np.interp(6, data,pdf)
# Out:
# 0.3122539333667612

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  
# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(-20, 20, 0.01)
  
# Calculating mean and standard deviation
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
  
plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()

# %%
import numpy as np
import pandas as pd
read = pd.read_csv("Crop_recommendation.csv")

read
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
from math import exp, sqrt, pi
def calculate_probability(x,mean,sd):
    exponent = exp(-0.5*((x-mean)/sd)**2)
    return ((1/(sd*sqrt(2*pi)))*exponent)

# %%
import matplotlib.pyplot as plt
import seaborn as sb

Nrice = []
Ncoffee = []
for i in range(len(read)):
    if read['label'][i] == 'rice':
        Nrice.append(read['N'][i])
    elif read['label'][i] == 'coffee':
        Ncoffee.append(read['N'][i])
        
x_axis = np.asarray(Nrice)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis,loc= mean, scale=sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'green')
plt.xlabel('N value')
plt.ylabel('Probability Density')

print(calculate_probability(98,mean,sd))

x_axis = Ncoffee
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, loc=mean, scale=sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'red')
plt.xlabel('N value')
plt.ylabel('Probability Density')

print(calculate_probability(98,mean,sd))
# Out:
# /home/akshajsr/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.009391231703160212
# /home/akshajsr/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.031414551910364595

# %%
import matplotlib.pyplot as plt
import seaborn as sb

Price = []
Pcoffee = []
for i in range(len(read)):
    if read['label'][i] == 'rice':
        Price.append(read['P'][i])
    elif read['label'][i] == 'coffee':
        Pcoffee.append(read['P'][i])

x_axis = np.asarray(Price)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'green')
plt.xlabel('P value')
plt.ylabel('Probability Density')

print(calculate_probability(47,mean,sd))
# LKR = np.interp(27, x_axis,y_axis)


x_axis = np.asarray(Pcoffee)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'red')
plt.xlabel('P value')
plt.ylabel('Probability Density')

print(calculate_probability(47,mean,sd))

print("0.009391231703160212 ×  0.05066572027672756  ×  0.1098478223669306 × 0.5 = 0.000026134")
print("0.0017195128781449835 × 0.1200038948430136 × 0.031414551910364595 × 0.5  = 0.000003241")
# LKC = np.interp(27, x_axis,y_axis)
# Out:
# /home/akshajsr/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.05066572027672756
# /home/akshajsr/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.0017195128781449835
# 0.009391231703160212 ×  0.05066572027672756  ×  0.1098478223669306 × 0.5 = 0.000026134
# 0.0017195128781449835 × 0.1200038948430136 × 0.031414551910364595 × 0.5  = 0.000003241

# %%
import matplotlib.pyplot as plt
import seaborn as sb

Krice = []
Kcoffee = []
for i in range(len(read)):
    if read['label'][i] == 'rice':
        Krice.append(read['K'][i])
    elif read['label'][i] == 'coffee':
        Kcoffee.append(read['K'][i])

x_axis = np.asarray(Krice)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'green')
plt.xlabel('K value')
plt.ylabel('Probability Density')

print(calculate_probability(37,mean,sd))

x_axis = np.asarray(Kcoffee)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'red')
plt.xlabel('K value')
plt.ylabel('Probability Density')

print(calculate_probability(37,mean,sd))
# Out:
# /home/akshajsr/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/akshajsr/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.1098478223669306
# 0.005142422126351767

# %%
import matplotlib.pyplot as plt
import seaborn as sb

temprice = []
tempcoffee = []
for i in range(len(read)):
    if read['label'][i] == 'rice':
        temprice.append(read['temperature'][i])
    elif read['label'][i] == 'coffee':
        tempcoffee.append(read['temperature'][i])

x_axis = np.asarray(temprice)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'green')
plt.xlabel('temp value')
plt.ylabel('Probability Density')

LTR = np.interp(24.99451759, x_axis,y_axis)

x_axis = np.asarray(tempcoffee)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'red')
plt.xlabel('temp value')
plt.ylabel('Probability Density')

LTC = np.interp(24.99451759, x_axis,y_axis)
# Out:
# /home/akshajsr/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/akshajsr/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import seaborn as sb

humidityrice = []
humiditycoffee = []
for i in range(len(read)):
    if read['label'][i] == 'rice':
        humidityrice.append(read['humidity'][i])
    elif read['label'][i] == 'coffee':
        humiditycoffee.append(read['humidity'][i])

x_axis = np.asarray(humidityrice)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'green')
plt.xlabel('temp value')
plt.ylabel('Probability Density')

LHR = np.interp(57.93250202, x_axis,y_axis)

x_axis = np.asarray(humiditycoffee)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'red')
plt.xlabel('temp value')
plt.ylabel('Probability Density')

LHC = np.interp(57.93250202, x_axis,y_axis)

# %%
import matplotlib.pyplot as plt
import seaborn as sb

phrice = []
phcoffee = []
for i in range(len(read)):
    if read['label'][i] == 'rice':
        phrice.append(read['ph'][i])
    elif read['label'][i] == 'coffee':
        phcoffee.append(read['ph'][i])

x_axis = np.asarray(phrice)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'green')
plt.xlabel('temp value')
plt.ylabel('Probability Density')

LPhR = np.interp(7.162802357, x_axis,y_axis)

x_axis = np.asarray(phcoffee)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'red')
plt.xlabel('temp value')
plt.ylabel('Probability Density')

LPhC = np.interp(7.162802357, x_axis,y_axis)

# %%
import matplotlib.pyplot as plt
import seaborn as sb

rainfallrice = []
rainfallcoffee = []
for i in range(len(read)):
    if read['label'][i] == 'rice':
        rainfallrice.append(read['rainfall'][i])
    elif read['label'][i] == 'coffee':
        rainfallcoffee.append(read['rainfall'][i])

# x_axis = np.asarray(rainfallrice)
# mean = statistics.mean(x_axis)
# sd = statistics.stdev(x_axis)
# y_axis = norm.pdf(x_axis, mean, sd)
# sb.set_style('whitegrid')
# sb.lineplot(x_axis, y_axis , color = 'green')
# plt.xlabel('temp value')
# plt.ylabel('Probability Density')

# LRR = np.interp(192.8736822, x_axis,y_axis)
# print(LRR)

x_axis = np.asarray(rainfallcoffee)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
y_axis = norm.pdf(x_axis, mean, sd)
sb.set_style('whitegrid')
sb.lineplot(x_axis, y_axis , color = 'red')
plt.xlabel('temp value')
plt.ylabel('Probability Density')

LRC = np.interp(192.8736822, x_axis,y_axis)
print(LRC)

# %% [markdown]
# if i have a value ->
# N : 114 , P : 27 ,  K : 28 , temp : 24.99451759 , humidity : 57.93250202 , ph : 7.162802357 rainfall  : 192.8736822 will it be rice or coffee??

# %%
# P(rice) ? 
# P(coffee) ?
lenrice = 0
lencoffee = 0  
for i in range(len(read)):
    if read['label'][i] == 'rice':
        lenrice+=1
    elif read['label'][i] == 'coffee':
        lencoffee+=1
print("no of rice :", lenrice," ","no of coffee  : ",lencoffee)

# probability of rice = probability of coffee = 100/100+100
PR =  lenrice/(lenrice+lencoffee)
PC =  lencoffee/(lenrice+lencoffee)

print("P(R) = ",PR)
print("P(C) = ",PC)

# %% [markdown]
# lets assume we have to plant rice, so
# Score = P(R) x L(N|R) x L(P|R) x L(K|R) x  L(temp|R) x L(humidity|R) x L(ph|R) x L(rainfall|R)

# %%
# Score for rice :

scoreRice = (PR*LNR*LPR*LKR*LTR*LHR*LPhR*LRR)/PR
scoreCoffee = (PC*LNC*LPC*LKC*LTC*LHC*LPhC*LRC)/PC
print(scoreRice,scoreCoffee)

# %%
# if one of it is zero so taking log
from math import log

scoreRice = log(PR)+log(LNR)+log(LPR)+log(LKR)+log(LTR)+log(LHR)+log(LPhR)+log(LRR)
scoreCoffee = log(PC)+log(LNC)+log(LPC)+log(LKC)+log(LTC)+log(LHC)+log(LPhC)+log(LRC)
print(scoreRice,scoreCoffee)

# %%
# since score of rice is greater that score of coffee, rice is the best crop to plant
